# %%
import csv

# %%
MY_FILE = "/Users/Saturnist/Google Drive/program/learn_python/dataviz/data/sample_sfpd_incident_all.csv"

# %%
def parse(raw_file, delimiter):
    
    opened_file = open(raw_file)
    
    csv_data = csv.reader(opened_file, delimiter=delimiter)
    
    parsed_data = []
    
    fields = next(csv_data)
    #alternatively can use csv_data.__next__()
    
    for row in csv_data:
        parsed_data.append(dict(zip(fields, row)))
        
    opened_file.close()
    
    return parsed_data

# %%
def main():
    
    new_data = parse(MY_FILE, ",")
    
    print(new_data)

# %%
if __name__ == "__main__":
    main()
# Out:
# [{'Resolution': 'NONE', 'Date': '02/18/2003', 'X': '-122.424612993055', 'DayOfWeek': 'Tuesday', 'Y': '37.8014488257836', 'Time': '16:30', 'PdDistrict': 'NORTHERN', 'IncidntNum': '030203898', 'Descript': 'FORGERY, CREDIT CARD', 'Location': '2800 Block of VAN NESS AV', 'Category': 'FRAUD'}, {'Resolution': 'ARREST, BOOKED', 'Date': '04/17/2003', 'X': '-122.420120319211', 'DayOfWeek': 'Thursday', 'Y': '37.7877570602182', 'Time': '22:45', 'PdDistrict': 'NORTHERN', 'IncidntNum': '000038261', 'Descript': 'WARRANT ARREST', 'Location': 'POLK ST / SUTTER ST', 'Category': 'WARRANTS'}, {'Resolution': 'NONE', 'Date': '02/18/2003', 'X': '-122.42025048261', 'DayOfWeek': 'Tuesday', 'Y': '37.7800745746105', 'Time': '16:05', 'PdDistrict': 'NORTHERN', 'IncidntNum': '030203901', 'Descript': 'GRAND THEFT PICKPOCKET', 'Location': 'VAN NESS AV / MCALLISTER ST', 'Category': 'LARCENY/THEFT'}, {'Resolution': 'ARREST, BOOKED', 'Date': '02/18/2003', 'X': '-122.390718076188', 'DayOfWeek': 'Tuesday', 'Y': '37.7385560584619', 'Time': '17:00', 'PdDistrict': 'BAYVIEW', 'IncidntNum': '030203923', 'Descript': 'SALE OF BASE/ROCK COCAINE', 'Location': '1600 Block of KIRKWOOD AV', 'Category': 'DRUG/NARCOTIC'}, {'Resolution': 'ARREST, BOOKED', 'Date': '02/18/2003', 'X': '-122.390718076188', 'DayOfWeek': 'Tuesday', 'Y': '37.7385560584619', 'Time': '17:00', 'PdDistrict': 'BAYVIEW', 'IncidntNum': '030203923', 'Descript': 'CONSPIRACY', 'Location': '1600 Block of KIRKWOOD AV', 'Category': 'OTHER OFFENSES'}, {'Resolution': 'ARREST, BOOKED', 'Date': '02/18/2003', 'X': '-122.390718076188', 'DayOfWeek': 'Tuesday', 'Y': '37.7385560584619', 'Time': '17:00', 'PdDistrict': 'BAYVIEW', 'IncidntNum': '030203923', 'Descript': 'PROBATION VIOLATION', 'Location': '1600 Block of KIRKWOOD AV', 'Category': 'OTHER OFFENSES'}, {'Resolution': 'ARREST, BOOKED', 'Date': '03/31/2003', 'X': '-122.433084166809', 'DayOfWeek': 'Monday', 'Y': '37.7851499161314', 'Time': '22:08', 'PdDistrict': 'NORTHERN', 'IncidntNum': '000324684', 'Descript': 'UNDER INFLUENCE OF ALCOHOL IN A PUBLIC PLACE', 'Location': 'POST ST / FILLMORE ST', 'Category': 'DRUNKENNESS'}, {'Resolution': 'ARREST, BOOKED', 'Date': '03/31/2003', 'X': '-122.433084166809', 'DayOfWeek': 'Monday', 'Y': '37.7851499161314', 'Time': '22:08', 'PdDistrict': 'NORTHERN', 'IncidntNum': '000324684', 'Descript': 'WARRANT ARREST', 'Location': 'POST ST / FILLMORE ST', 'Category': 'WARRANTS'}, {'Resolution': 'ARREST, BOOKED', 'Date': '02/22/2003', 'X': '-122.422727873548', 'DayOfWeek': 'Saturday', 'Y': '37.7503729275448', 'Time': '17:35', 'PdDistrict': 'MISSION', 'IncidntNum': '000335471', 'Descript': 'WARRANT ARREST', 'Location': '25TH ST / GUERRERO ST', 'Category': 'WARRANTS'}, {'Resolution': 'ARREST, BOOKED', 'Date': '04/01/2003', 'X': '-122.403675174069', 'DayOfWeek': 'Tuesday', 'Y': '37.7751775072045', 'Time': '15:00', 'PdDistrict': 'SOUTHERN', 'IncidntNum': '000454598', 'Descript': 'WARRANT ARREST', 'Location': '800 Block of BRYANT ST', 'Category': 'WARRANTS'}, {'Resolution': 'ARREST, BOOKED', 'Date': '04/16/2003', 'X': '-122.411451390903', 'DayOfWeek': 'Wednesday', 'Y': '37.7831610223684', 'Time': '00:40', 'PdDistrict': 'TENDERLOIN', 'IncidntNum': '000474320', 'Descript': 'WARRANT ARREST', 'Location': '100 Block of TURK ST', 'Category': 'WARRANTS'}, {'Resolution': 'NONE', 'Date': '03/17/2003', 'X': '0', 'DayOfWeek': 'Monday', 'Y': '0', 'Time': '15:38', 'PdDistrict': '', 'IncidntNum': '000522662', 'Descript': 'STOLEN TRUCK', 'Location': 'OUT OF TOWN', 'Category': 'VEHICLE THEFT'}, {'Resolution': 'NONE', 'Date': '03/17/2003', 'X': '0', 'DayOfWeek': 'Monday', 'Y': '0', 'Time': '15:38', 'PdDistrict': '', 'IncidntNum': '000522662', 'Descript': 'VEHICLE, RECOVERED, OTHER VEHICLE', 'Location': 'OUT OF TOWN', 'Category': 'VEHICLE THEFT'}, {'Resolution': 'ARREST, BOOKED', 'Date': '03/06/2003', 'X': '-122.403675174069', 'DayOfWeek': 'Thursday', 'Y': '37.7751775072045', 'Time': '19:00', 'PdDistrict': 'SOUTHERN', 'IncidntNum': '000644777', 'Descript': 'WARRA ...
